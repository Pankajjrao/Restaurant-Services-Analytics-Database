# %%
import pandas as pd
import numpy as np
import re
import html
from number_parser import parse_ordinal

# %%
df = pd.read_csv("Open_Restaurant_Applications__Historic__20231202_t.csv")

# %%
df.shape
# Out:
# (14428, 35)

# %%
pd.set_option("display.max_columns", None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14428 entries, 0 to 14427
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   objectid                                  14428 non-null  int64
#  1   globalid                                  14428 non-null  object
#  2   Seating Interest (Sidewalk/Roadway/Both)  14428 non-null  object
#  3   Restaurant Name                           14427 non-null  object
#  4   Legal Business Name                       14427 non-null  object
#  5   Doing Business As (DBA)                   14416 non-null  object
#  6   Building Number                           12776 non-null  object
#  7   Street                                    14428 non-null  object
#  8   Borough                                   14428 non-null  object
#  9   Postcode                                  14428 non-null  int64
#  10  Business Address                          14428 non-null  object
#  11  Food Service Establishment Permit #       14422 non-null  object
#  12  Sidewalk Dimensions (Length)              12118 non-null  float64
#  13  Sidewalk Dimensions (Width)               12118 non-null  float64
#  14  Sidewalk Dimensions (Area)                12118 non-null  float64
#  15  Roadway Dimensions (Length)               9054 non-null   float64
#  16  Roadway Dimensions (Width)                9054 non-null   float64
#  17  Roadway Dimensions (Area)                 9054 non-null   float64
#  18  Approved for Sidewalk Seating             14428 non-null  object
#  19  Approved for Roadway Seating              14428 non-null  object
#  20  Qualify Alcohol                           14428 non-null  object
#  21  SLA Serial Number                         9448 non-null   object
#  22  SLA License Type                          9449 non-null   object
#  23  Landmark District or Building             14428 non-null  object
#  24  landmarkDistrict_terms                    2129 non-null   object
#  25  healthCompliance_terms                    14428 non-null  object
#  26  Time of Submission                        14428 non-null  object
#  27  Latitude                                  13121 non-null  float64
#  28  Longitude                                 13121 non-null  float64
#  29  Community Board                           13121 non-null  float64
#  30  Council District                          13121 non-null  float64
#  31  Census Tract                              13121 non-null  float64
#  32  BIN                                       13026 non-null  float64
#  33  BBL                                       13026 non-null  float64
#  34  NTA                                       13121 non-null  object
# dtypes: float64(13), int64(2), object(20)
# memory usage: 3.9+ MB

# %%
# checking numerical columns in the dataset

numerics = ["int16", "int32", "int64", "float16", "float32", "float64"]

total_numerical_cols = len(df.select_dtypes(numerics).columns)
total_numerical_cols

# there are 15 numerical columns and 25 non-numerical columns
# Out:
# 15

# %%
df.describe()
# Out:
#            objectid      Postcode  Sidewalk Dimensions (Length)  \
# count  14428.000000  14428.000000                  12118.000000
# mean    7266.598766  10594.626074                     32.959894
# std     4184.357841    922.296122                     34.496100
# min       32.000000   7002.000000                      0.000000
# 25%     3641.750000  10016.000000                     15.000000
# 50%     7266.500000  10303.000000                     24.000000
# 75%    10893.250000  11220.000000                     40.000000
# max    14516.000000  91206.000000                   1000.000000
#
#        Sidewalk Dimensions (Width)  Sidewalk Dimensions (Area)  \
# count                 12118.000000                12118.000000
# mean                     10.132283                  372.778099
# std                       6.954057                  926.289956
# min                       0.000000                    0.000000
# 25%                       6.000000                  108.000000
# 50%                       8.000000                  206.000000
# 75%                      13.000000                  400.000000
# max                      50.000000                50000.000000
#
#        Roadway Dimensions (Length)  Roadway Dimensions (Width)  \
# count                  9054.000000                 9054.000000
# mean                     30.820853                    8.205324
# std                      26.737258                    3.364510
# min                       0.000000                    0.000000
# 25%                      18.000000                    8.000000
# 50%                      24.000000                    8.000000
# 75%                      36.000000                    8.000000
# max                    1000.000000                   50.000000
#
#        Roadway Dimensions (Area)      Latitude     Longitude  Community Board  \
# count                9054.000000  13121.000000  13121.000000     13121.000000
# mean                  259.750497     40.733412    -73.953890         5.218581
# std                   401.388896      0.056158      0.059173         3.635352
# min                     0.000000     40.511019    -74.248014         1.000000
# 25%                   128.000000     40.707473    -73.990251         2.000000
# 50%                   192.000000     40.734734    -73.970537         5.000000
# 75%                   296.000000     40.761872    -73.926113         7.000000
# max                 25000.000000     40.911190    -73.702668        81.000000
#
#        Council District   Census Tract           BIN           BBL
# count      13121.000000   13121.000000  1.302600e+04  1.302600e+04
# mean          17.203948    2928.269187  2.248597e+06  2.194042e+09
# std           15.279790   12812.777168  1.308012e+06  1.273212e+09
# min            1.000000       1.000000  1.000000e+06  0.000000e+00
# 25%            3.000000      69.000000  1.025026e+06  1.008400e+09
# 50%           11.000000     149.000000  2.003088e+06  2.024115e+09
# 75%           33.000000     466.000000  3.212196e+06  3.054050e+09
# max           51.000000  157903.000000  5.169029e+06  5.080430e+09

# %%
# chcking the percent of null values in each column

round(df.isnull().sum().sort_values(ascending=False) / len(df) * 100, 2)
# Out:
# landmarkDistrict_terms                      85.24
# Roadway Dimensions (Area)                   37.25
# Roadway Dimensions (Length)                 37.25
# Roadway Dimensions (Width)                  37.25
# SLA Serial Number                           34.52
# SLA License Type                            34.51
# Sidewalk Dimensions (Length)                16.01
# Sidewalk Dimensions (Width)                 16.01
# Sidewalk Dimensions (Area)                  16.01
# Building Number                             11.45
# BIN                                          9.72
# BBL                                          9.72
# Census Tract                                 9.06
# Council District                             9.06
# Community Board                              9.06
# Latitude                                     9.06
# Longitude                                    9.06
# NTA                                          9.06
# Doing Business As (DBA)                      0.08
# Food Service Establishment Permit #          0.04
# Restaurant Name                              0.01
# Legal Business Name                          0.01
# Approved for Sidewalk Seating                0.00
# Postcode                                     0.00
# Seating Interest (Sidewalk/Roadway/Both)     0.00
# Street                                       0.00
# Borough                                      0.00
# Time of Submission                           0.00
# Approved for Roadway Seating                 0.00
# healthCompliance_terms                       0.00
# Business Address                             0.00
# Landmark District or Building                0.00
# globalid                                     0.00
# Qualify Alcohol                              0.00
# objectid                                     0.00
# dtype: float64

# %% [markdown]
# # Changes needed to be done
# - Drop landmarkDistrict_terms column
# - Remove {} from the rows of globalid column
# - Change Dtype of  Time of Submission column
# - Remove html tags from the columns
# - Make columns title
# - Make business entity abbreviations in correct format (from Llc to LLC and Inc... to Inc. etc)
# - Make NY upper case again (which became title due to previous step)
# - Give proper suffix to digits in the columns (61St to 61st)
# - Replace the Nan and undefiend values in the Building number column with actual building number
# - Remove the building number from street column
# - SLA column should have a serial number but instead some rows have a month-number like(july-79) etc (I think it should be dropped)

# %% [markdown]
# ### Dropping the landmarkDistrict_terms column

# %%
df = df.drop(["landmarkDistrict_terms"], axis=1)

# %% [markdown]
# ### Removing {} from the rows of globalid column

# %%
df["globalid"] = df["globalid"].str.strip("{}")

# %% [markdown]
# ### Chainging Dtype of Time of Submission column

# %%
df["Time of Submission"] = pd.to_datetime(df["Time of Submission"])

# %% [markdown]
# ### function to remove the html tags from the values in column

# %%
def html_content_remover(column):
    return column.apply(lambda x: html.unescape(str(x)))

# %% [markdown]
# ### removing html tags form various columns

# %%
df["Restaurant Name"] = html_content_remover(df["Restaurant Name"])
df["Doing Business As (DBA)"] = html_content_remover(df["Doing Business As (DBA)"])
df["Legal Business Name"] = html_content_remover(df["Legal Business Name"])

# %% [markdown]
# ### function to make title of all the values in the column and correct the problems that arise due to title

# %%
def make_title_and_corrections(df, column):
    df[column] = df[column].str.title()
    
    df[column] = df[column].fillna("")
    
    pattern = r'\b(\d+)(Th|Nd|St|Rd)\b'
    pattern_1 = r'\b([A-Za-z]+)(\'[A-Z])\b'
    corp_pattern = r'\bCorp(?:oration|orations)?(?![.])\b'
    inc_pattern = r'\bInc(?:orporated)?(?![.])\b'

    df[column] = df[column].apply(lambda x : re.sub(pattern, lambda m: m.group(1) + m.group(2).lower(), x))
    df[column] = df[column].apply(lambda x: re.sub(pattern_1,lambda m : m.group(1) + m.group(2).lower(),x ))
    
    df[column] = df[column].str.replace("Llc","LLC")
    df[column] = df[column].str.replace(inc_pattern,"Inc.",regex=True)
    df[column] = df[column].str.replace(corp_pattern,"Corp.",regex=True)

# %%
make_title_and_corrections(df, "Restaurant Name")
make_title_and_corrections(df, "Legal Business Name")
make_title_and_corrections(df, "Doing Business As (DBA)")

# %% [markdown]
# ### Function to fill the Building Number column(replace NaN and undefiend values with the building numbers)

# %%
def fill_building_number(dataframe, business_address: str, building_number: str):
    # Iterate over the rows of the DataFrame
    for index, row in df.iterrows():
        # checking if this at cuurent row building number is None or 'undefined'
        if pd.isna(row[building_number]) or row[building_number] == "undefined":

            first_word = row[business_address].split()[0]
            # if it is then split the business address at current index and take the first object and put it in first_word variable

            df.at[index, building_number] = first_word
            # Assigning the value of first_word variable to the building number at that row


fill_building_number(df, "Business Address", "Building Number")

# %% [markdown]
# ### Function to remove building number from  Street column

# %%
def street_transformation(dataframe, street_col, building_number_col):
    '''This function removes Building number from the street column'''

    for index, row in df.iterrows():

        # storing the first word of Street column at each row in first_word variable
        first_word = row[street_col].split()[0]

        # checking if building is equal to the first_word
        if row[building_number_col] == first_word:
            new_street = " ".join(row[street_col].split()[1:])
            # splitting the street at each row and indexing from 1 then joining it

            df.at[index, street_col] = new_street
            # replacing the value of street at a specific index with the value of new_street

street_transformation(df, "Street", "Building Number")

# %% [markdown]
# ### Making Ny upper case again accross the Business Address column

# %%
df["Business Address"] = df["Business Address"].str.replace(r"\bNy\b", "NY", regex=True)

# %% [markdown]
# -------------------- =============== --------------------------------------

# %% [markdown]
# ## Changes to be made in street column
#
# - Capitalize the street column
# - if there are suffix behind street numbers make them proper like in column [12660, 10488, ]
# - if the steet number don't have suffix the add proper suffix to them [6391, 11583,12314]
# - Ave to Avenue, Boulevard to Blvd , St., to Street if St in last  [7114,5934,12021]
# - Words to digits [12021, ]

# %%
def column_tansformation(df,column):
    df[column] = df[column].str.title()
    
    
    def what(x):

        def is_ordinal(word):
            ordinal_words = ['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth', 'Seventh', 'Eighth', 'Ninth', 'Tenth']
            return word in ordinal_words

        l = x.split()

        for i in range(len(l)):
            if is_ordinal(l[i]):
                parsed_word = parse_ordinal(l[i])
                l[i] = str(parsed_word)

        return " ".join(l)
            
    
    
    def ordinal(m):
        n = int(m.group())
        if 5 <= n <= 20 :
            suffix = 'th'
        else:
            remainder = n % 10
            if remainder == 1:
                suffix = 'st'
            elif remainder == 2:
                suffix = 'nd'
            elif remainder == 3:
                suffix = 'rd'
            else:
                suffix = 'th'
        output = str(n) + suffix
        return output
    
    pattern = r'\b(\d+)(Th|Nd|St|Rd)\b'
    ave_pattern = r'\bAve\.?$|\bAve\b|\bAv\b'
    st_pattern = r'\bSt\.?$\b|\bSt\b'
    blvd_pattern = r'\bBlvd\b'
    number = r'\b\d+\b'
    
    
    df[column] = df[column].apply(lambda x : re.sub(pattern, lambda m: m.group(1) + m.group(2).lower(), str(x)))
    df[column] = df[column].str.replace(ave_pattern, 'Avenue', regex = True)
    df[column] = df[column].str.replace(st_pattern, 'Street', regex = True)
    df[column] = df[column].str.replace(blvd_pattern, 'Boulevard', regex = True)
    df[column] = df[column].apply(what)
    df[column] = df[column].str.replace(re.compile(number), lambda x: ordinal(x), regex=True)
    

    
    
    
column_tansformation(df,"Street")

# %% [markdown]
# ## Combining the Building number + Street + Borough columns + NY = Business Address

# %%
df["Business Address"] = df.apply(lambda row: f"{row['Building Number']}, {row['Street']}, {row['Borough']}, NY", axis=1)

# %%
df
# Out:
#        objectid                              globalid  \
# 0         13610  FD87ABAA-860E-4762-845D-8F0403D0246B
# 1          5900  3B07E4C0-07B7-4079-8333-64446CC3EE03
# 2         13018  137C575D-DC14-4F9D-83D9-A3FFE513B3B8
# 3         11630  15270732-2A78-4C24-89DD-BE8DD916F115
# 4         13137  EF9C8173-91D1-496E-8BD4-B02BEADC2A21
# ...         ...                                   ...
# 14423      9799  108C6784-54DB-480B-8627-CF0495D27A0E
# 14424      8215  7B8EC275-D470-4106-819E-03FC0E1F9717
# 14425      2895  476f88d2-d3e8-4e83-8686-8bac2f752cf5
# 14426       607  ff0d04ef-1d9a-47d6-8f20-8bdbdbce2792
# 14427      6641  9DBBF87C-AE3D-4487-81A4-30E44806614F
#
#       Seating Interest (Sidewalk/Roadway/Both)          Restaurant Name  \
# 0                                      roadway             Madame Bonte
# 1                                     sidewalk           Seasoned Vegan
# 2                                     sidewalk    Americas Cafe & Grill
# 3                                      roadway               Sushi Seki
# 4                                      roadway              Sami & Susu
# ...                                        ...                      ...
# 14423                                     both      King Of Spades Inc.
# 14424                                     both  La Queen Tea House Inc.
# 14425                                 sidewalk     Aahar Indina Cuisine
# 14426                                 sidewalk           Le Cafe Coffee
# 14427                                     both         Kashkaval Garden
#
#            Legal Business Name  Doing Business As (DBA) Building Number  \
# 0                Beanhouse LLC             Madame Bonte             318
# 1          Seasoned Vegan, LLC      Seasoned Vegan, LLC              55
# 2              68th Grill Inc.    Americas Cafe & Grill            1159
# 3                    Seki Inc.               Sushi Seki             208
# 4                  Amir Nathan              Sami & Susu             190
# ...                        ...                      ...             ...
# 14423      King Of Spades Inc.      King Of Spades Inc.            1425
# 14424  La Queen Tea House Inc.  La Queen Tea House Inc.            752B
# 14425        Vidhan Bhatt Inc.        Vidhan Bhatt Inc.              10
# 14426       Le Cafe Coffee LLC       Le Cafe Coffee LLC             145
# 14427    Kashkaval Kitchen LLC    Kashkaval Kitchen LLC             852
#
#                         Street    Borough  Postcode  \
# 0             East 84th Street  Manhattan     10028
# 1      Street. Nicholas Avenue  Manhattan     10026
# 2                   3rd Avenue  Manhattan     10065
# 3             West 23rd Street  Manhattan     10011
# 4               Orchard Street  Manhattan     10002
# ...                        ...        ...       ...
# 14423  College Point Boulevard     Queens     11356
# 14424              61st Street   Brooklyn     11220
# 14425            Murray Street  Manhattan     10007
# 14426               4th Avenue  Manhattan     10003
# 14427               9th Avenue  Manhattan     10019
#
#                                  Business Address  \
# 0            318, East 84th Street, Manhattan, NY
# 1      55, Street. Nicholas Avenue, Manhattan, NY
# 2                 1159, 3rd Avenue, Manhattan, NY
# 3            208, West 23rd Street, Manhattan, NY
# 4              190, Orchard Street, Manhattan, NY
# ...                                           ...
# 14423   1425, College Point Boulevard, Queens, NY
# 14424             752B, 61st Street, Brooklyn, NY
# 14425            10, Murray Street, Manhattan, NY
# 14426              145, 4th Avenue, Manhattan, NY
# 14427              852, 9th Avenue, Manhattan, NY
#
#       Food Service Establishment Permit #  Sidewalk Dimensions (Length)  \
# 0                                50114174                           NaN
# 1                                50003337                          47.0
# 2                                40797684                           8.0
# 3                                50005983                           NaN
# 4                                50112624                           NaN
# ...                                   ...                           ...
# 14423                            50072483                          22.0
# 14424                            50105060                          26.0
# 14425                            50049997                          25.0
# 14426                            50042698                          10.0
# 14427                            41713066                          10.0
#
#        Sidewalk Dimensions (Width)  Sidewalk Dimensions (Area)  \
# 0                              NaN                         NaN
# 1                              3.0                       141.0
# 2                              8.0                        64.0
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 14423                          4.0                        88.0
# 14424                          7.0                       182.0
# 14425                         14.0                       350.0
# 14426                         10.0                       100.0
# 14427                          3.0                        30.0
#
#        Roadway Dimensions (Length)  Roadway Dimensions (Width)  \
# 0                             10.0                         8.0
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                             44.0                         8.0
# 4                             22.0                         8.0
# ...                            ...                         ...
# 14423                         22.0                         8.0
# 14424                         26.0                         8.0
# 14425                          NaN                         NaN
# 14426                          NaN                         NaN
# 14427                         10.0                         3.0
#
#        Roadway Dimensions (Area) Approved for Sidewalk Seating  \
# 0                           80.0                            no
# 1                            NaN                           yes
# 2                            NaN                           yes
# 3                          352.0                            no
# 4                          176.0                            no
# ...                          ...                           ...
# 14423                      176.0                           yes
# 14424                      208.0                           yes
# 14425                        NaN                           yes
# 14426                        NaN                           yes
# 14427                       30.0                           yes
#
#       Approved for Roadway Seating Qualify Alcohol SLA Serial Number  \
# 0                              yes             yes           1346965
# 1                               no             yes           1289526
# 2                               no              no               NaN
# 3                              yes             yes            Aug-82
# 4                              yes             yes            Jul-61
# ...                            ...             ...               ...
# 14423                          yes             yes            Feb-05
# 14424                          yes              no               NaN
# 14425                           no             yes           1298882
# 14426                           no              no               NaN
# 14427                          yes             yes            May-67
#
#       SLA License Type Landmark District or Building healthCompliance_terms  \
# 0                   TW                            no                    yes
# 1                   RW                            no                    yes
# 2                  NaN                            no                    yes
# 3                   OP                            no                    yes
# 4                   TW                            no                    yes
# ...                ...                           ...                    ...
# 14423               OP                            no                    yes
# 14424              NaN                            no                    yes
# 14425               RW                            no                    yes
# 14426              NaN                            no                    yes
# 14427               OP                            no                    yes
#
#        Time of Submission   Latitude  Longitude  Community Board  \
# 0     2022-06-09 16:26:00  40.776277 -73.952051              8.0
# 1     2020-06-26 20:38:00  40.800500 -73.952507             10.0
# 2     2021-10-22 11:01:00  40.766845 -73.962708              8.0
# 3     2020-12-14 19:54:00  40.744338 -73.996240              4.0
# 4     2021-12-22 12:46:00  40.722124 -73.988160              3.0
# ...                   ...        ...        ...              ...
# 14423 2020-08-04 15:27:00  40.784739 -73.845776              7.0
# 14424 2020-07-13 15:53:00  40.635543 -74.011220              7.0
# 14425 2020-06-21 13:46:00  40.713298 -74.007773              1.0
# 14426 2020-06-19 13:19:00  40.733916 -73.989872              3.0
# 14427 2020-06-30 22:33:00  40.766927 -73.986423              4.0
#
#        Council District  Census Tract        BIN           BBL  \
# 0                   5.0         138.0  1049941.0  1.015460e+09
# 1                   9.0         216.0  1054995.0  1.018220e+09
# 2                   4.0         118.0  1043896.0  1.014220e+09
# 3                   3.0          91.0  1014129.0  1.007720e+09
# 4                   1.0        3001.0  1005393.0  1.004120e+09
# ...                 ...           ...        ...           ...
# 14423              19.0         929.0  4098349.0  4.040850e+09
# 14424              38.0         118.0  3143885.0  3.057940e+09
# 14425               1.0          21.0  1001399.0  1.001240e+09
# 14426               2.0          42.0  1077569.0  1.005590e+09
# 14427               3.0         139.0  1025423.0  1.010460e+09
#
#                                               NTA
# 0                                       Yorkville
# 1                            Central Harlem South
# 2                     Lenox Hill-Roosevelt Island
# 3      Hudson Yards-Chelsea-Flatiron-Union Square
# 4                                       Chinatown
# ...                                           ...
# 14423                               College Point
# 14424                            Sunset Park East
# 14425      SoHo-TriBeCa-Civic Center-Little Italy
# 14426                                East Village
# 14427                                     Clinton
#
# [14428 rows x 34 columns]

# %%
### DON"T DELETE THIS CELL IT IS IMPORTANT

def ordinal(m: str):
        n = int(m.group())
        if 11 <= (n % 100) <= 13:
            suffix = 'th'
        else:
            suffix = ['th', 'st', 'nd', 'rd', 'th'][min(n % 10, 4)]
        output = str(n) + suffix
        return output


line = "this is 52 street 123"
number = r'\b\d+\b'
pattern = re.compile(number)
out = re.sub(pattern,lambda x : ordinal(x),line)
print(out)
# Out:
# this is 52nd street 123rd

# %% [markdown]
# ### Handling values in SLA Serial Number Column (contains ###, and month-random_two_digit values)

# %%
series = (df["SLA Serial Number"].str.match(r"^[A-Za-z]+\-\d+|\#+") & (df["Qualify Alcohol"] == 'yes'))
df.loc[series, "SLA Serial Number"] = "TO BE DEFINED"

# %% [markdown]
# ### Capitalizing Seating Interest (Sidewalk/Roadway/Both) column

# %%
df["Seating Interest (Sidewalk/Roadway/Both)"] = df['Seating Interest (Sidewalk/Roadway/Both)'].str.capitalize()

# %% [markdown]
# ## Saving into csv

# %%
df.to_csv("Cleaned_ORA_historic.csv",index=False)
