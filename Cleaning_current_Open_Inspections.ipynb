# %%
import pandas as pd
import numpy as np
import html
import re
from number_parser import parse_ordinal

# %%
df = pd.read_csv("currentOpenInspections_p.csv")

# %%
df.shape
# Out:
# (79203, 20)

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79203 entries, 0 to 79202
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Borough                 79203 non-null  object
#  1   RestaurantName          79195 non-null  object
#  2   SeatingChoice           79203 non-null  object
#  3   LegalBusinessName       79202 non-null  object
#  4   BusinessAddress         79203 non-null  object
#  5   RestaurantInspectionID  79203 non-null  int64
#  6   IsSidewayCompliant      0 non-null      float64
#  7   IsRoadwayCompliant      79203 non-null  object
#  8   SkippedReason           19866 non-null  object
#  9   InspectedOn             79203 non-null  object
#  10  AgencyCode              67240 non-null  object
#  11  Postcode                79203 non-null  int64
#  12  Latitude                71320 non-null  float64
#  13  Longitude               71320 non-null  float64
#  14  CommunityBoard          71320 non-null  float64
#  15  CouncilDistrict         71320 non-null  float64
#  16  CensusTract             71320 non-null  float64
#  17  BIN                     70899 non-null  float64
#  18  BBL                     70899 non-null  float64
#  19  NTA                     71320 non-null  object
# dtypes: float64(8), int64(2), object(10)
# memory usage: 12.1+ MB

# %%
# checking numerical columns in the dataset

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df.select_dtypes(include=numerics).shape[1]

# so there are 10numerical columns in the dataset and rest 10 are non-numerical columns s
# Out:
# 10

# %%
# checking the percentage of null values in each column
missing_values_percentage = round(df.isnull().sum().sort_values(ascending=False)/len(df) * 100, 2)
missing_values_percentage
# Out:
# IsSidewayCompliant        100.00
# SkippedReason              74.92
# AgencyCode                 15.10
# BBL                        10.48
# BIN                        10.48
# Latitude                    9.95
# CensusTract                 9.95
# CouncilDistrict             9.95
# CommunityBoard              9.95
# Longitude                   9.95
# NTA                         9.95
# RestaurantName              0.01
# LegalBusinessName           0.00
# Postcode                    0.00
# InspectedOn                 0.00
# IsRoadwayCompliant          0.00
# RestaurantInspectionID      0.00
# BusinessAddress             0.00
# SeatingChoice               0.00
# Borough                     0.00
# dtype: float64

# %% [markdown]
# ### there are 2 columns in the dataset which have more than 50 percent null values

# %% [markdown]
# ## Changes need to be done
# - Drop IsSidewayCompliant column.
# - Drop SkippedReason column.
# - Change Dtype of InspectedOn column from oject to datetime
# - Removing html tags from the columns
# - Break down the businessAddress column into BuildingNumber and Street columns
# - Clean the Street column
# - Replace BusinessAddress column with combined values of BuildingNumber + Street + Borough + "NY"
# - Change the position of columns

# %% [markdown]
# ### dropping IsSidewayCompliant column.

# %%
df = df.drop(["IsSidewayCompliant"],axis=1)

# %% [markdown]
# ### dropping SkippedReason column.

# %%
df = df.drop(["SkippedReason"],axis=1)

# %% [markdown]
# ### chainging the data type of column named InspectedOn

# %%
df['InspectedOn'] = pd.to_datetime(df['InspectedOn'])

# %%
df.iloc[[76663,16438,37353]]
# Out:
#          Borough                 RestaurantName SeatingChoice  \
# 76663  Manhattan        SUCKER PUNCH SPORTS BAR       roadway
# 16438     Queens  Paraiso Colombiano Restaurant          both
# 37353     Queens        NEW MALAYSIA RESTAURANT       roadway
#
#                   LegalBusinessName    BusinessAddress  \
# 76663  SUCKER PUNCH SPORTS CLUB LLC       344 3 AVENUE
# 16438             106 20 Food Corp.  106 20  Corona Av
# 37353          MALAY RESTAURANT INC      13517 40 ROAD
#
#        RestaurantInspectionID  IsRoadwayCompliant         InspectedOn  \
# 76663                  100910  Skipped Inspection 2023-06-23 10:56:58
# 16438                    1476       Non-Compliant 2020-07-05 08:15:13
# 37353                   31071               Reset 2020-12-22 09:05:24
#
#       AgencyCode  Postcode   Latitude  Longitude  CommunityBoard  \
# 76663        DOT     10010  40.740321 -73.982076             6.0
# 16438        DOT     11368  40.743727 -73.856279             4.0
# 37353        NaN     11354        NaN        NaN             NaN
#
#        CouncilDistrict  CensusTract        BIN           BBL       NTA
# 76663              2.0         68.0  1018110.0  1.008810e+09  Gramercy
# 16438             21.0        439.0  4447721.0  4.019350e+09    Corona
# 37353              NaN          NaN        NaN           NaN       NaN

# %%
df.sample(10)
# Out:
#          Borough                    RestaurantName SeatingChoice  \
# 15836     Queens               M. Wells Steakhouse          both
# 20711   Brooklyn                         Roberta's          both
# 71121   Brooklyn      Nuevo M+?xico Bar Restaurant          both
# 30184  Manhattan   Le Pain Quotidien - Bryant Park          both
# 43613     Queens                Taqueria Coatzingo       roadway
# 25473  Manhattan                          Park Bar          both
# 65181   Brooklyn                          Fritebar      sidewalk
# 67216  Manhattan             Fiaschetteria Pistoia          both
# 29499  Manhattan                   Thyme and Tonic          both
# 78121      Bronx  Evo Cocktail Lounge & Restaurant          both
#
#                LegalBusinessName        BusinessAddress  \
# 15836      M. Wells Crescent LLC  43-15 Crescent Street
# 20711  Nineteen Twenty Four, Inc       271 Moore Street
# 71121         Nuevo M+?xico Inc.       489   5th Avenue
# 30184     APQ Bryant Park NY LLC    70 West 40th Street
# 43613           76 Taqueria Corp    76-05 Roosevelt Ave
# 25473         Steeplechase, Inc.    15 East 15th Street
# 65181             NA Frites Inc.        8503 3rd Avenue
# 67216          Fiaschetteria LTD   647 East 11th street
# 29499       Spring Natural Corp.           474 Columbus
# 78121        Mi Gente Caf+? Inc.     1306 Unionport Rd.
#
#        RestaurantInspectionID  IsRoadwayCompliant         InspectedOn  \
# 15836                   13189  Skipped Inspection 2020-07-23 17:28:26
# 20711                   19848           Compliant 2020-08-25 15:40:02
# 71121                   92190           Compliant 2022-11-11 10:30:01
# 30184                   30855               Reset 2020-12-22 09:05:24
# 43613                   43437           Compliant 2021-01-26 17:41:32
# 25473                   24585  Skipped Inspection 2020-09-30 14:16:45
# 65181                     722       Non-Compliant 2020-07-03 16:51:56
# 67216                    8574       Non-Compliant 2020-07-13 14:26:55
# 29499                   30206               Reset 2020-12-22 09:05:24
# 78121                  102438        Under Review 2023-08-07 17:34:13
#
#       AgencyCode  Postcode   Latitude  Longitude  CommunityBoard  \
# 15836        DOT     11101  40.748674 -73.942323             2.0
# 20711        DOT     11206  40.704891 -73.933680             1.0
# 71121        DOT     11215  40.667599 -73.987603             6.0
# 30184        NaN     10018  40.753266 -73.984379             5.0
# 43613        DOT     11372  40.747063 -73.889413             3.0
# 25473        DOT     10003  40.736499 -73.992635             5.0
# 65181        DOT     11209  40.624182 -74.030753            10.0
# 67216        DOB     10009  40.726720 -73.977678             3.0
# 29499        NaN     10024        NaN        NaN             NaN
# 78121        DOT     10462  40.834275 -73.853738             9.0
#
#        CouncilDistrict  CensusTract        BIN           BBL  \
# 15836             26.0         19.0  4436807.0  4.004340e+09
# 20711             34.0        485.0  3325964.0  3.031010e+09
# 71121             39.0        139.0  3022922.0  3.010230e+09
# 30184              4.0         84.0  1016059.0  1.008410e+09
# 43613             25.0        287.0  4439244.0  4.012870e+09
# 25473              2.0         52.0  1087180.0  1.008438e+09
# 65181             43.0         62.0  3153101.0  3.060340e+09
# 67216              2.0         28.0  1004914.0  1.003940e+09
# 29499              NaN          NaN        NaN           NaN
# 78121             18.0        222.0  2028985.0  2.039340e+09
#
#                                               NTA
# 15836        Hunters Point-Sunnyside-West Maspeth
# 20711                              Bushwick South
# 71121                          Park Slope-Gowanus
# 30184                       Midtown-Midtown South
# 43613                             Jackson Heights
# 25473  Hudson Yards-Chelsea-Flatiron-Union Square
# 65181                                   Bay Ridge
# 67216                             Lower East Side
# 29499                                         NaN
# 78121                                 Parkchester

# %%
# Making seatingChoice title
df["SeatingChoice"] = df["SeatingChoice"].str.capitalize()

# %% [markdown]
# ### function to remove the html tags from the values in column

# %%
def html_content_remover(column):
    return column.apply(lambda x: html.unescape(str(x)))

# %%
df["RestaurantName"] = html_content_remover(df["RestaurantName"])
df["LegalBusinessName"] = html_content_remover(df["LegalBusinessName"])

# %% [markdown]
# ### Function to make business entity abbreviations correct

# %%
def make_title_and_corrections(df, column):
    df[column] = df[column].str.title()
    
    df[column] = df[column].fillna("")
    
    pattern = r'\b(\d+)(Th|Nd|St|Rd)\b'                     # For names like 12th , 2nd etc
    pattern_1 = r'\b([A-Za-z]+)(\'[A-Z])\b'                 # for names like Sam's, Macdonald's
    corp_pattern = r'\bCorp(?:oration|orations)?(?![.])\b'
    inc_pattern = r'\bInc(?:orporated)?(?![.])\b'

    df[column] = df[column].apply(lambda x : re.sub(pattern, lambda m: m.group(1) + m.group(2).lower(), x))
    df[column] = df[column].apply(lambda x: re.sub(pattern_1,lambda m : m.group(1) + m.group(2).lower(),x ))
    
    df[column] = df[column].str.replace("Llc","LLC")
    df[column] = df[column].str.replace(inc_pattern,"Inc.",regex=True)
    df[column] = df[column].str.replace(corp_pattern,"Corp.",regex=True)

# %%
make_title_and_corrections(df,"RestaurantName")
make_title_and_corrections(df,"LegalBusinessName")

# %% [markdown]
# ## Taking out buildingNumber and Street form business_Address column

# %%
def building(df,column):
    """return two lists contianing buildingNumbers and street_name"""
    
    building_list = []
    street_name = []
    for i in df[column]:
        split_address = i.split()                                                # splitting the column on space
        building_number = split_address[0] if len(split_address) > 1 else None   # taking the first value of split as builidng number 
        street = " ".join(split_address[1:]) if building_number else " ".join(split_address)   # taking all values strting from 1 as street from split_address
        building_list.append(building_number)
        street_name.append(street)
    return building_list,street_name



        
df["BuildingNumber"], df["Street"] = building(df, "BusinessAddress")

# %%
# checking nulls in BuildingNumber
df[df["BuildingNumber"].isna()]
# Out:
#         Borough RestaurantName SeatingChoice LegalBusinessName  \
# 6065   Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 6066   Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 6496   Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 17639  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 24423  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 30928  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 33282  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 43421  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 43422  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
# 52551  Brooklyn      Mr Fulton          Both   Bk Fulton Corp.
#
#       BusinessAddress  RestaurantInspectionID         IsRoadwayCompliant  \
# 6065             156a                   79872         Skipped Inspection
# 6066             156a                   79873             Pre-Suspension
# 6496             156a                   80233  Suspended and Deactivated
# 17639            156a                   16700         Skipped Inspection
# 24423            156a                   23541         Skipped Inspection
# 30928            156a                   31542                      Reset
# 33282            156a                   26403         Skipped Inspection
# 43421            156a                   43258         Skipped Inspection
# 43422            156a                   43259         Skipped Inspection
# 52551            156a                    5570         Skipped Inspection
#
#               InspectedOn AgencyCode  Postcode  Latitude  Longitude  \
# 6065  2022-04-25 15:52:54        DOT     11201       NaN        NaN
# 6066  2022-04-25 15:52:54        DOT     11201       NaN        NaN
# 6496  2022-05-02 00:00:01        NaN     11201       NaN        NaN
# 17639 2020-08-01 11:37:53        DOT     11201       NaN        NaN
# 24423 2020-09-21 17:48:22        DOT     11201       NaN        NaN
# 30928 2020-12-22 09:05:24        NaN     11201       NaN        NaN
# 33282 2020-10-28 12:00:41        DOT     11201       NaN        NaN
# 43421 2021-01-26 13:49:49        DOT     11201       NaN        NaN
# 43422 2021-01-26 13:50:43        DOT     11201       NaN        NaN
# 52551 2020-07-08 20:15:14        DEP     11201       NaN        NaN
#
#        CommunityBoard  CouncilDistrict  CensusTract  BIN  BBL  NTA  \
# 6065              NaN              NaN          NaN  NaN  NaN  NaN
# 6066              NaN              NaN          NaN  NaN  NaN  NaN
# 6496              NaN              NaN          NaN  NaN  NaN  NaN
# 17639             NaN              NaN          NaN  NaN  NaN  NaN
# 24423             NaN              NaN          NaN  NaN  NaN  NaN
# 30928             NaN              NaN          NaN  NaN  NaN  NaN
# 33282             NaN              NaN          NaN  NaN  NaN  NaN
# 43421             NaN              NaN          NaN  NaN  NaN  NaN
# 43422             NaN              NaN          NaN  NaN  NaN  NaN
# 52551             NaN              NaN          NaN  NaN  NaN  NaN
#
#       BuildingNumber Street
# 6065            None   156a
# 6066            None   156a
# 6496            None   156a
# 17639           None   156a
# 24423           None   156a
# 30928           None   156a
# 33282           None   156a
# 43421           None   156a
# 43422           None   156a
# 52551           None   156a

# %%
# Droping Nulls from df subset buildingNumber
df.dropna(subset=["BuildingNumber"], inplace=True)

# %%
# Checking nulls in street column
df[df["Street"].isna()]
# Out:
# Empty DataFrame
# Columns: [Borough, RestaurantName, SeatingChoice, LegalBusinessName, BusinessAddress, RestaurantInspectionID, IsRoadwayCompliant, InspectedOn, AgencyCode, Postcode, Latitude, Longitude, CommunityBoard, CouncilDistrict, CensusTract, BIN, BBL, NTA, BuildingNumber, Street]
# Index: []

# %% [markdown]
# ## Cleaning street column

# %%
def column_tansformation(df,column):
    df[column] = df[column].str.title()
    
    
    def what(x):

        def is_ordinal(word):
            ordinal_words = ['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth', 'Seventh', 'Eighth', 'Ninth', 'Tenth']
            return word in ordinal_words

        l = x.split()

        for i in range(len(l)):
            if is_ordinal(l[i]):
                parsed_word = parse_ordinal(l[i])
                l[i] = str(parsed_word)

        return " ".join(l)
            
    
    
    def ordinal(m):
        n = int(m.group())
        if 5 <= n <= 20 :
            suffix = 'th'
        else:
            remainder = n % 10
            if remainder == 1:
                suffix = 'st'
            elif remainder == 2:
                suffix = 'nd'
            elif remainder == 3:
                suffix = 'rd'
            else:
                suffix = 'th'
        output = str(n) + suffix
        return output
    
    pattern = r'\b(\d+)(Th|Nd|St|Rd)\b'
    ave_pattern = r'\bAve\.?$|\bAve\b|\bAv\b'
    st_pattern = r'\bSt\.?$\b|\bSt\b'
    blvd_pattern = r'\bBlvd\b'
    number = r'\b\d+\b'
    
    
    df[column] = df[column].apply(lambda x : re.sub(pattern, lambda m: m.group(1) + m.group(2).lower(), str(x)))
    df[column] = df[column].str.replace(ave_pattern, 'Avenue', regex = True)
    df[column] = df[column].str.replace(st_pattern, 'Street', regex = True)
    df[column] = df[column].str.replace(blvd_pattern, 'Boulevard', regex = True)
    df[column] = df[column].apply(what)
    df[column] = df[column].str.replace(re.compile(number), lambda x: ordinal(x), regex=True)
    

    
    
    
column_tansformation(df,"Street")

# %% [markdown]
# ## Combining the Building number + Street + Borough columns + NY = Business Address

# %%
df["BusinessAddress"] = df.apply(lambda row: f"{row['BuildingNumber']}, {row['Street']}, {row['Borough']}, NY", axis=1)

# %%
df.sample(5)
# Out:
#          Borough                     RestaurantName SeatingChoice  \
# 66441   Brooklyn                    Weather Up & Co          Both
# 36767  Manhattan             A&T Fish And Chips LLC       Roadway
# 29995   Brooklyn                            Abilene          Both
# 15441     Queens                            Fayrooz          Both
# 65837  Manhattan  Leonelli Focacceria E Pasticceria          Both
#
#               LegalBusinessName                       BusinessAddress  \
# 66441                Ward 8 LLC  589, Vanderbilt Avenue, Brooklyn, NY
# 36767    A&T Fish And Chips LLC         85, 1st Avenue, Manhattan, NY
# 29995              Leahlala LLC       442, Court Street, Brooklyn, NY
# 15441  Atlantic East Group Inc.    28-08, Steinway Street, Queens, NY
# 65837  Leonelli Restaurants LLC           7, East 27th, Manhattan, NY
#
#        RestaurantInspectionID  IsRoadwayCompliant         InspectedOn  \
# 66441                    7848  Skipped Inspection 2020-07-12 14:27:55
# 36767                   36979     For HIQA Review 2021-01-11 09:31:34
# 29995                    3068           Compliant 2020-07-07 15:33:06
# 15441                   12826       Non-Compliant 2020-07-21 22:17:09
# 65837                   72866       Non-Compliant 2021-12-20 13:34:19
#
#       AgencyCode  Postcode   Latitude  Longitude  CommunityBoard  \
# 66441        DOB     11238  40.679936 -73.968035             8.0
# 36767        NaN     10003  40.725937 -73.986503             3.0
# 29995        DEP     11231  40.678933 -73.997563             6.0
# 15441        DOT     11103  40.765240 -73.913909             1.0
# 65837        DOT     10016  40.743843 -73.987196             5.0
#
#        CouncilDistrict  CensusTract        BIN           BBL  \
# 66441             35.0        203.0  3027904.0  3.011380e+09
# 36767              2.0         38.0  1077690.0  1.004478e+09
# 29995             39.0         65.0  3005293.0  3.003660e+09
# 15441             22.0       6502.0  4010771.0  4.006620e+09
# 65837              2.0         56.0  1016886.0  1.008570e+09
#
#                                               NTA BuildingNumber  \
# 66441                            Prospect Heights            589
# 36767                                East Village             85
# 29995    Carroll Gardens-Columbia Street-Red Hook            442
# 15441                                     Astoria          28-08
# 65837  Hudson Yards-Chelsea-Flatiron-Union Square              7
#
#                   Street
# 66441  Vanderbilt Avenue
# 36767         1st Avenue
# 29995       Court Street
# 15441    Steinway Street
# 65837          East 27th

# %% [markdown]
# ## Chainging the postion of columns

# %%
# Adding column names in a list
column_list = []
for column in df:
    column_list.append(column)

# %%
# chinging the placement of columns
column_list = ['Borough',
 'RestaurantName',
 'SeatingChoice',
 'LegalBusinessName',
 'BuildingNumber',
 'Street',
 'BusinessAddress',
 'RestaurantInspectionID',
 'IsRoadwayCompliant',
 'InspectedOn',
 'AgencyCode',
 'Postcode',
 'Latitude',
 'Longitude',
 'CommunityBoard',
 'CouncilDistrict',
 'CensusTract',
 'BIN',
 'BBL',
 'NTA'
 ]

df = df.loc[:, column_list]  # Applying the placement inplace

# %%
df
# Out:
#          Borough             RestaurantName SeatingChoice  \
# 0      Manhattan                Oscar Wilde          Both
# 1      Manhattan        La Rubia Restaurant          Both
# 2      Manhattan               Thai Sliders      Sidewalk
# 3       Brooklyn                      Otway          Both
# 4       Brooklyn  Williamsburg Thai Cuisine          Both
# ...          ...                        ...           ...
# 79198   Brooklyn                Sunshine Co          Both
# 79199  Manhattan                  Moustache      Sidewalk
# 79200   Brooklyn                Mekelburg's          Both
# 79201   Brooklyn         Sunday In Brooklyn          Both
# 79202   Brooklyn                      Otway          Both
#
#                        LegalBusinessName BuildingNumber            Street  \
# 0                     Camelot Castle LLC             45  West 27th Street
# 1               La Rubia Restaurant Inc.           3517          Broadway
# 2                        Silom Thai Inc.            150        8th Avenue
# 3                       St James 930 LLC            930     Fulton Street
# 4      Williamsburg Thai Cuisine Ny Inc.            212    Bedford Avenue
# ...                                  ...            ...               ...
# 79198                 780 Washington LLC            780  Wahington Avenue
# 79199                Bedford Pitza Corp.             29  7th Avenue South
# 79200         Hop, Stock & Barrel Ii LLC            319       Kent Avenue
# 79201             Sunday In Brooklyn LLC            348      Wythe Avenue
# 79202                   St James 930 LLC            930     Fulton Street
#
#                            BusinessAddress  RestaurantInspectionID  \
# 0      45, West 27th Street, Manhattan, NY                   72891
# 1            3517, Broadway, Manhattan, NY                   72892
# 2           150, 8th Avenue, Manhattan, NY                   72893
# 3         930, Fulton Street, Brooklyn, NY                   72894
# 4        212, Bedford Avenue, Brooklyn, NY                   72896
# ...                                    ...                     ...
# 79198  780, Wahington Avenue, Brooklyn, NY                  107873
# 79199  29, 7th Avenue South, Manhattan, NY                  107874
# 79200       319, Kent Avenue, Brooklyn, NY                  107875
# 79201      348, Wythe Avenue, Brooklyn, NY                  107876
# 79202     930, Fulton Street, Brooklyn, NY                  107877
#
#        IsRoadwayCompliant         InspectedOn AgencyCode  Postcode   Latitude  \
# 0           Non-Compliant 2021-12-20 16:06:58        DOT     10001  40.744876
# 1         For HIQA Review 2021-12-20 16:18:42        DOT     10031  40.825863
# 2           Non-Compliant 2021-12-20 16:35:41        DOT     10011  40.741906
# 3        Cease and Desist 2021-12-20 16:38:45        DOT     11238  40.682833
# 4               Compliant 2021-12-20 16:52:41        DOT     11249  40.716913
# ...                   ...                 ...        ...       ...        ...
# 79198         Pre-Removal 2023-12-01 15:44:49        DOT     11238        NaN
# 79199    Cease and Desist 2023-12-01 16:13:28        DOT     10014  40.730812
# 79200  Skipped Inspection 2023-12-01 16:42:51        DOT     11238  40.713757
# 79201           Compliant 2023-12-01 16:48:20        DOT     11249  40.714171
# 79202     For HIQA Review 2023-12-01 17:00:48        DOT     11238  40.682833
#
#        Longitude  CommunityBoard  CouncilDistrict  CensusTract        BIN  \
# 0     -73.989657             5.0              3.0         58.0  1015677.0
# 1     -73.950874             9.0              7.0        229.0  1062369.0
# 2     -74.000945             4.0              3.0         81.0  1013845.0
# 3     -73.963833             2.0             35.0        201.0  3335112.0
# 4     -73.958728             1.0             33.0        553.0  3062192.0
# ...          ...             ...              ...          ...        ...
# 79198        NaN             NaN              NaN          NaN        NaN
# 79199 -74.004395             2.0              3.0         67.0  1087324.0
# 79200 -73.967200             1.0             33.0        551.0  3424711.0
# 79201 -73.965208             1.0             33.0        551.0  3321284.0
# 79202 -73.963833             2.0             35.0        201.0  3335112.0
#
#                 BBL                                         NTA
# 0      1.008290e+09  Hudson Yards-Chelsea-Flatiron-Union Square
# 1      1.020910e+09                            Hamilton Heights
# 2      1.007670e+09  Hudson Yards-Chelsea-Flatiron-Union Square
# 3      3.020130e+09                                Clinton Hill
# 4      3.023350e+09                       North Side-South Side
# ...             ...                                         ...
# 79198           NaN                                         NaN
# 79199  1.005860e+09                                West Village
# 79200  3.024280e+09                       North Side-South Side
# 79201  3.024150e+09                       North Side-South Side
# 79202  3.020130e+09                                Clinton Hill
#
# [79193 rows x 20 columns]

# %%
# 
df.to_csv("Cleaned_current_open_inspections.csv",index=False)
